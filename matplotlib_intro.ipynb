# %% [markdown]
# # 參考資料
# [學習計劃-帶你10周入門資料分析](https://medium.com/%E6%95%B8%E6%93%9A%E5%88%86%E6%9E%90%E4%B8%8D%E6%98%AF%E5%80%8B%E4%BA%8B/%E5%AD%B8%E7%BF%92%E8%A8%88%E5%8A%83-%E5%B8%B6%E4%BD%A010%E5%91%A8%E5%85%A5%E9%96%80%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90-66a48503e1b2)
#
# [Python資料分析（五）Matplotlib做視覺化](https://medium.com/@allaboutdataanalysis/python%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90-%E4%BA%94-matplotlib%E5%81%9A%E8%A6%96%E8%A6%BA%E5%8C%96-9d94f1d29dd0)

# %%
import matplotlib.pyplot as plt
import numpy as np

from numpy.random import randn

# %% [markdown]
# # Figure and subplot
# * 一次就要跑完以下程式碼才能顯示一個圖表 fig
# * 沒指定 axes 時，預設在最後一個 axes繪圖
#
# > 還可以通過sharex和sharey指定subplot應該具有相同的X軸或Y軸（刻度），在比較相同範圍的資料時用，否則matplotlib會自動縮放各圖表的界限。

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot(randn(50).cumsum(), 'k--')
_ = ax1.hist(randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %% [markdown]
# * 建立圖表後，可使用 array index 方式去取得指定位置物件

# %%
fig, axes = plt.subplots(2,3)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000177A44A46D8>,
# ...
#       dtype=object)

# %%
axes[0, 1]

# %% [markdown]
# # 調整subplot周圍的間距

# %%
fig, axes = plt.subplots(2,2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# # 顏色、標記和線型
# > 完整的linestyle列表參見plot的文檔。
# ax.plot(x, y, ‘g — ‘) #根據x, y繪製綠色虛線
# ax.plot(x, y, linestyle=’ — ‘, color=’g’)
#
# > 要使用其他任意顏色可以通過指定其 RGB 值的形式（如 #CECECE）
# matplotlib創建的是連續的線型圖，即點與點之間插值，非實際資料點預設是按線性方式插值的，可以通過drawstyle選項修改

# %%
data = randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 'k--', drawstyle='steps-post', label='Steps-post')

# %%
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k--', drawstyle='steps-post', label='Steps-post')
plt.legend(loc='best')

# %%
plt.plot(data, color='k', linestyle='dashed', marker='o')

# %%
# use 'ko--'' 
# instead of color='k', linestyle='dashed', marker='o'
plt.plot(data, 'ko--')

# %% [markdown]
# # 刻度、標籤和圖例
# > 互動式使用，有xlim, xticks, xticklabels之類的方法，它們分別控制圖表的範圍，刻度位置，刻度標籤等。
# 調用時不帶引數，如plt.xlim()返回當前的X軸繪圖範圍。
# 調用時帶引數，如plt.xlim([0, 10])會將X軸的範圍設定為 0 到 10。
# 更為物件導向的原生matplotlib API。

# %% [markdown]
# # 設定標題、軸標籤、刻度以及刻度標籤
